# %% [markdown]
# # Pandas_Basics

# %%
import pandas as pd

# %% [markdown]
# ## 1-Creating data

# %% [markdown]
# there are two methods to creating data :
# DataFrame AND Series

# %%
#Creating data By using : DataFrame
pd.DataFrame({'yes':[10,15,20],'No':[2,8,3]})
# Out:
#    yes  No
# 0   10   2
# 1   15   8
# 2   20   3

# %%
#Creating data By using : DataFrame
pd.DataFrame({'Name':['Sara' , 'Salah','Ahmed'],'Age':[22,21,23]})
# Out:
#     Name  Age
# 0   Sara   22
# 1  Salah   21
# 2  Ahmed   23

# %%
#Creating data By using : DataFrame
pd.DataFrame({'Nmae':['Sara' ,'Salah','Ahmed'] ,'Birth_Date':['15/4' ,'13/8','']},index=['First_Name','Second_name','Third_Name'])
# Out:
#               Nmae Birth_Date
# First_Name    Sara       15/4
# Second_name  Salah       13/8
# Third_Name   Ahmed

# %%
#Creating data By using : Series
pd.Series(['Name','Age','DateOfBirth','Adress'])
# Out:
# 0           Name
# 1            Age
# 2    DateOfBirth
# 3         Adress
# dtype: object

# %%
#Creating data By using : Series
pd.Series([100,22,33,44],index=['One','Two','Three','Four'],name='Exercise')
# Out:
# One      100
# Two       22
# Three     33
# Four      44
# Name: Exercise, dtype: int64

# %% [markdown]
# ## 2-Reading Data File

# %%
# pd.read_csv()
import pandas as pd
data = pd.read_csv("Student_Behaviour.csv")
data
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                   No
# 1                                                   No
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0      Male        BCA       100.0        58.0       79.0       65.0
# 1    Female        BCA        90.0        40.0       70.0       80.0
# ...

# %% [markdown]
# ### - Understanding Data

# %%
data.head() #First 5 rows
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
# 2    Male        BCA       159.0        78.0       69.5       61.0
# 3  Female        BCA       147.0        20.0       70.0       59.0
# 4    Male        BCA       170.0        54.0       40.0       65.0
#
#    college mark        hobbies daily studing time prefer to study in  \
# 0          80.0    Video Games      0 - 30 minute            Morning
# ...

# %%
data.shape #(reows,columns)
# Out:
# (235, 19)

# %%
data.info() #the type of each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 19 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   Have you completed any certification courses, or are you currently enrolled in any?  235 non-null    object
#  1   Gender                                                                               235 non-null    object
#  2   Department                                                                           235 non-null    object
#  3   Height(CM)                                                                           235 non-null    float64
#  4   Weight(KG)                                                                           235 non-null    float64
# ...

# %%
data.columns.values #columns_name
# Out:
# array(['Have you completed any certification courses, or are you currently enrolled in any?',
#        'Gender', 'Department', 'Height(CM)', 'Weight(KG)', '10th Mark',
#        '12th Mark', 'college mark', 'hobbies', 'daily studing time',
#        'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'possibility of choosing  their career based on their degree : ',
#        'social medai & video games spending Time', 'Travelling Time ',
#        'Stress Level ', 'Financial Status',
#        'Are you doing a part-time job right now?'], dtype=object)

# %%
data.hobbies
# Out:
# 0        Video Games
# 1             Cinema
# 2             Cinema
# 3      Reading books
# 4        Video Games
#            ...
# 230      Video Games
# 231           Cinema
# 232           Cinema
# 233           Cinema
# 234           Sports
# Name: hobbies, Length: 235, dtype: object

# %% [markdown]
# ### Difference between loc & and iloc
# The main difference between pandas loc[] vs iloc[] is loc gets DataFrame rows & columns by labels/names and iloc[] gets by integer Index/position

# %%
data.loc[[0,1,2,3]] #show wanted rows
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
# 2    Male        BCA       159.0        78.0       69.5       61.0
# 3  Female        BCA       147.0        20.0       70.0       59.0
#
#    college mark        hobbies daily studing time prefer to study in  \
# 0          80.0    Video Games      0 - 30 minute            Morning
# 1          70.0         Cinema     30 - 60 minute            Morning
# 2          55.0         Cinema         1 - 2 Hour            Anytime
# ...

# %%
data.loc[0]
# Out:
# Have you completed any certification courses, or are you currently enrolled in any?                 No
# Gender                                                                                            Male
# Department                                                                                         BCA
# Height(CM)                                                                                       100.0
# Weight(KG)                                                                                        58.0
# 10th Mark                                                                                         79.0
# 12th Mark                                                                                         65.0
# college mark                                                                                      80.0
# hobbies                                                                                    Video Games
# ...

# %%
data.loc[[0,1]]
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
#
#    college mark      hobbies daily studing time prefer to study in  \
# 0          80.0  Video Games      0 - 30 minute            Morning
# 1          70.0       Cinema     30 - 60 minute            Morning
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
#
#   possibility of choosing  their career based on their degree :   \
# 0                                                50%
# 1                                                75%
#
# ...

# %%
data.loc[0:3,'Gender']
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3    Female
# Name: Gender, dtype: object

# %%
data.iloc[: , :  ] #[rows,columns]
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                   No
# 1                                                   No
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0      Male        BCA       100.0        58.0       79.0       65.0
# 1    Female        BCA        90.0        40.0       70.0       80.0
# ...

# %%
data.iloc[:,-1] #Last coulumn
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
#        ..
# 230    No
# 231    No
# 232    No
# 233    No
# 234    No
# Name: Are you doing a part-time job right now?, Length: 235, dtype: object

# %%
data.iloc[-5:] #last five rows
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 230    Male  B.com ISM       170.0        76.0       72.0       67.0
# 231    Male  B.com ISM       172.0        52.0       72.0       70.0
# 232  Female        BCA       139.0        33.0       90.0       75.0
# 233  Female   Commerce       153.0        58.0       85.0       74.0
# 234  Female  B.com ISM       155.0        39.0       45.0       45.0
#
#      college mark      hobbies daily studing time prefer to study in  \
# 230          65.0  Video Games     30 - 60 minute            Morning
# ...

# %%
data.iloc[[0, 1, 2], [0,3]]
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
#
#    Height(CM)
# 0       100.0
# 1        90.0
# 2       159.0

# %%
data.loc[0:3,'Gender']
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3    Female
# Name: Gender, dtype: object

# %% [markdown]
# ### Indexing

# %%
data.set_index("Department") #make the coloumns is the index of dataset
# Out:
#            Have you completed any certification courses, or are you currently enrolled in any?  \
# Department
# BCA                                                        No
# BCA                                                        No
# BCA                                                       Yes
# BCA                                                       Yes
# BCA                                                        No
# ...                                                       ...
# B.com ISM                                                 Yes
# B.com ISM                                                 Yes
# BCA                                                       Yes
# Commerce                                                  Yes
# B.com ISM                                                  No
#
#             Gender  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# Department
# BCA           Male       100.0        58.0       79.0       65.0
# ...

# %% [markdown]
# ### Filtering DataFrame

# %%
data[data['Gender']=='Female'] #Select the female from Gender column
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 1                                                   No
# 3                                                  Yes
# 5                                                  Yes
# 11                                                  No
# 12                                                 Yes
# ..                                                 ...
# 226                                                Yes
# 229                                                 No
# 232                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 1    Female        BCA        90.0        40.0       70.0       80.0
# 3    Female        BCA       147.0        20.0       70.0       59.0
# ...

# %%
data.Gender=='Female'
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 230    False
# 231    False
# 232     True
# 233     True
# 234     True
# Name: Gender, Length: 235, dtype: bool

# %%
data.loc[data.Gender=='Female']
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 1                                                   No
# 3                                                  Yes
# 5                                                  Yes
# 11                                                  No
# 12                                                 Yes
# ..                                                 ...
# 226                                                Yes
# 229                                                 No
# 232                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 1    Female        BCA        90.0        40.0       70.0       80.0
# 3    Female        BCA       147.0        20.0       70.0       59.0
# ...

# %%
data.loc[(data.Gender=='Female') &(data.hobbies=='Cinema')]
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 1                                                   No
# 5                                                  Yes
# 11                                                  No
# 19                                                 Yes
# 22                                                  No
# 37                                                  No
# 42                                                  No
# 60                                                 Yes
# 61                                                 Yes
# 72                                                  No
# 81                                                 Yes
# 86                                                 Yes
# 90                                                 Yes
# 96                                                 Yes
# 111                                                Yes
# ...

# %%
data.loc[data.Department.isin(['Commerce','BCA'])] #show rows thas has im Department "['Commerce','BCA']"
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                   No
# 1                                                   No
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 224                                                Yes
# 225                                                Yes
# 226                                                Yes
# 232                                                Yes
# 233                                                Yes
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0      Male        BCA       100.0        58.0       79.0       65.0
# 1    Female        BCA        90.0        40.0       70.0       80.0
# ...

# %% [markdown]
# ### Statistics with Pandas

# %%
data['salary expectation'].sum()
# Out:
# 7633195

# %%
data['salary expectation'].mean()
# Out:
# 32481.68085106383

# %%
data[['salary expectation','Height(CM)']].max()
# Out:
# salary expectation    1500000.0
# Height(CM)                192.0
# dtype: float64

# %%
data.mode()
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                Yes
# 1                                                NaN
# 2                                                NaN
#
#   Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0   Male        BCA       160.0        60.0       60.0       60.0
# 1    NaN        NaN         NaN         NaN       75.0       70.0
# 2    NaN        NaN         NaN         NaN       80.0        NaN
#
#    college mark hobbies daily studing time prefer to study in  \
# 0          70.0  Sports     30 - 60 minute            Anytime
# 1           NaN     NaN                NaN                NaN
# 2           NaN     NaN                NaN                NaN
#
#    salary expectation Do you like your degree?  \
# 0             20000.0                      Yes
# 1                 NaN                      NaN
# 2                 NaN                      NaN
#
# ...

# %% [markdown]
# ### Grouping

# %%
data.groupby("Gender").sum()
# Out:
#         Height(CM)  Weight(KG)  10th Mark  12th Mark  college mark  \
# Gender
# Female     11877.5      3987.0     6239.0    5665.50       6072.80
# Male       25112.0     10301.9    11818.9   10497.83      10532.43
#
#         salary expectation
# Gender
# Female             3015035
# Male               4618160

# %%
data.groupby("salary expectation").sum()
# Out:
#                     Height(CM)  Weight(KG)  10th Mark  12th Mark  college mark
# salary expectation
# 0                        162.0        60.0       62.0      61.30         53.00
# 10                       310.0        78.0       90.0      90.00        100.00
# 15                       152.0        32.0       80.0      60.00         70.00
# 17                       160.0        52.0       50.0      55.00         50.00
# 21                       171.0        60.0       78.0      55.00         70.00
# 22                       168.0        75.0       75.0      65.00         75.00
# 100                      160.0        50.0       85.0      80.00         60.00
# 500                      155.0        68.0       75.0      75.00         65.00
# 5000                     482.0       193.0      221.2     234.50        217.00
# 7000                     170.0        76.0       72.0      67.00         65.00
# 8000                     157.0        53.0       85.0      88.00         89.00
# ...

# %% [markdown]
# ### Sorting

# %%
height_sorted=data.sort_values("Height(CM)") //Sorting Columns
height_sorted
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 96                                                 Yes
# 1                                                   No
# 47                                                  No
# 25                                                  No
# 41                                                  No
# ..                                                 ...
# 73                                                 Yes
# 8                                                   No
# 163                                                Yes
# 62                                                 Yes
# 164                                                 No
#
#      Gender                     Department  Height(CM)  Weight(KG)  10th Mark  \
# 96   Female                            BCA         4.5        42.0       85.0
# 1    Female                            BCA        90.0        40.0       70.0
# ...

# %%
sortedd=data.sort_values(["Weight(KG)"])
sortedd
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 3                                                  Yes
# 210                                                Yes
# 5                                                  Yes
# 232                                                Yes
# 41                                                  No
# ..                                                 ...
# 77                                                 Yes
# 183                                                Yes
# 67                                                 Yes
# 42                                                  No
# 163                                                Yes
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 3    Female        BCA       147.0        20.0       70.0       59.0
# 210  Female   Commerce       152.0        32.0       80.0       60.0
# ...

# %%
data.groupby(['college mark', "Department"]).agg({'salary expectation':['sum', 'max']}) #do a function to spasfic columns
# Out:
#                                            salary expectation
#                                                           sum    max
# college mark Department
# 1.0          B.com Accounting and Finance               15000  15000
# 2.0          B.com ISM                                  23000  23000
# 3.0          BCA                                        15000  15000
# 7.5          BCA                                        15000  15000
# 12.0         B.com Accounting and Finance               30000  30000
# ...                                                       ...    ...
# 93.0         Commerce                                   20000  20000
# 95.0         B.com Accounting and Finance               50000  50000
#              Commerce                                   15000  15000
# 97.0         Commerce                                   15000  15000
# 100.0        Commerce                                   30000  15000
#
# [69 rows x 2 columns]

# %% [markdown]
# ### Pivot Tables

# %%
import numpy as np
data.pivot_table(index=["salary expectation"], columns=["Department"],  aggfunc=[np.sum])
# Out:
#                                              sum                             \
#                                        10th Mark
# Department         B.com Accounting and Finance  B.com ISM     BCA Commerce
# salary expectation
# 0                                            NaN       NaN    62.0      NaN
# 10                                           NaN      90.0     NaN      NaN
# 15                                           NaN       NaN     NaN     80.0
# 17                                           NaN       NaN    50.0      NaN
# 21                                           NaN       NaN    78.0      NaN
# 22                                           NaN       NaN     NaN     75.0
# 100                                          NaN       NaN     NaN     85.0
# 500                                          NaN      75.0     NaN      NaN
# 5000                                       161.2      60.0     NaN      NaN
# ...
